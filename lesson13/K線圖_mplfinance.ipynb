# %% [markdown]
# # K線圖
# https://pypi.org/project/mplfinance/

# %%
# !pip install mplfinance yfinance

# %%
import pandas as pd
import yfinance as yt
from datetime import datetime
import mplfinance as mpf

# %%
# 取得歷史股價
today = datetime.today().strftime('%Y-%m-%d')
df = yt.download('2317.TW', start='2016-01-01', end=today)
df.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2024-08-15  185.5  186.0  181.0  181.0      181.0  83391282
# 2024-08-16  186.0  187.0  183.0  184.0      184.0  72396121
# 2024-08-19  185.0  188.0  184.5  187.0      187.0  57256994
# 2024-08-20  189.5  191.0  186.0  186.5      186.5  80711041
# 2024-08-21  185.0  186.0  181.5  183.5      183.5  71607014

# %%
mpf.plot(df[-30:])

# %%
mpf.plot(df[-30:], type='candle')

# %%
mpf.plot(df, type='line')

# %%
mpf.plot(df, type='pnf')
# Out:
# /home/chesterxalan/github/Classwork/Classwork-PythonMLApplicationDevelopment/.venv/lib/python3.12/site-packages/mplfinance/_utils.py:129: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   high = highs[i]
# /home/chesterxalan/github/Classwork/Classwork-PythonMLApplicationDevelopment/.venv/lib/python3.12/site-packages/mplfinance/_utils.py:130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   low = lows[i]
# /home/chesterxalan/github/Classwork/Classwork-PythonMLApplicationDevelopment/.venv/lib/python3.12/site-packages/mplfinance/_utils.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   close_prev = closes[i-1]

# %%
mpf.plot(df[-300:], type='candle', mav=(5, 20, 60))

# %%
mpf.plot(df[-300:], type='candle', mav=(5, 20, 60), volume=True)

# %% [markdown]
# ## Style
# https://github.com/matplotlib/mplfinance/blob/master/examples/styles.ipynb

# %%
mpf.plot(df[-30:], type='candle', style='charles')

# %%
mc = mpf.make_marketcolors(up='g',down='r')
s  = mpf.make_mpf_style(marketcolors=mc)
mpf.plot(df[-30:], type='candle', style=s)
