# %% [markdown]
# # 偏導數(Partial Derivatives)
# ### 針對某一變數微分，其他變數視為常數。以下對x進行偏微分。
# ### $\begin{equation}f'(x,y) = \frac{d}{dx}f(x,y) = \lim_{h \to 0} \frac{f(x + h,y) - f(x,y)}{h} \end{equation}$

# %% [markdown]
# ## 範例
# ### $f(x,y) = x^2 + y^2$
# ### 對x進行偏微分。
# ### $\frac{\partial f(x,y)}{\partial x} = \frac{\partial (x^2 + y^2)}{\partial x}$
# ### $\frac{\partial x^2}{\partial x} = 2x$
# ### $\frac{\partial y^2}{\partial x} = 0$
# ### $\frac{\partial f(x,y)}{\partial x} = 2x + 0 = 2x$
# ### 對y進行偏微分。
# ### $\frac{\partial f(x,y)}{\partial y} = 0 + 2y = 2y$

# %% [markdown]
# ## 計算梯度(gradient)，梯度就是多元函數的斜率

# %% [markdown]
# ### $f(x,y) = x^2 + y^2$. These partial derivatives are:
#
# ### $\frac{\partial f(x,y)}{\partial x} = 2x$
# ### $\frac{\partial f(x,y)}{\partial y} = 2y$
#
# ### $grad(f(x,y)) =  \vec{g(x,y)} = \begin{bmatrix}\frac{\partial f(x,y)}{\partial x} \\ \frac{\partial f(x,y)}{\partial y} \end{bmatrix} = \begin{bmatrix}2x \\ 2y \end{bmatrix} $

# %% [markdown]
# ## 梯度下降法(Gradient Descent)

# %%
# 載入套件
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# 目標函數(損失函數):y=x^2
f = lambda x: x ** 2 

# 目標函數的一階導數:dy/dx=2*x
df = lambda x: 2 * x

# %%
# 梯度下降函數
# x_start: x的起始點
# df: 目標函數的一階導數
# epochs: 執行週期
# lr: 學習率
def GD(w_start, epochs, lr):    
    w_list = np.zeros(epochs+1)    
    w = w_start    
    w_list[0] = w    
    for i in range(epochs):         
        # w更新 w_new = w — learning_rate * gradient        
        w -= lr * df(w)         
        w_list[i+1] = w    
    return w_list

# %% [markdown]
# ## 執行梯度下降(Gradient Descent)

# %%
# 超參數(Hyperparameters)
w_start = 5     # 起始權重 -5, -3
epochs = 15     # 執行週期數 
lr = 0.3        # 學習率 0.01, 0.9

# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
w = GD(w_start, epochs, lr=lr) 
print('w的變化軌跡：', np.around(w, 2))

# 設定中文字型
fm.fontManager.addfont("../fonts/msjh.ttc")
plt.rcParams['font.family'] = fm.FontProperties(fname="../fonts/msjh.ttc").get_name()
# 矯正負號
plt.rcParams['axes.unicode_minus'] = False

color = 'r'    
t = np.arange(-6.0, 6.0, 0.01)
plt.plot(t, f(t), c='b')
plt.plot(w, f(w), c=color, label='lr={}'.format(lr))    
plt.scatter(w, f(w), c=color, ) 

plt.title('梯度下降法', fontsize=20)
plt.xlabel('W', fontsize=20)
plt.ylabel('損失函數', fontsize=20)
plt.show()
# Out:
# w的變化軌跡： [5.   2.   0.8  0.32 0.13 0.05 0.02 0.01 0.   0.   0.   0.   0.   0.
#  0.   0.  ]

# %% [markdown]
# ## 練習：請調整超參數，觀察梯度下降法的執行結果。

# %% [markdown]
# # 其他範例

# %% [markdown]
# ## 範例1.
# ### $x^3-2x+100$

# %% [markdown]
# ## 範例2. 假定損失函數如下，請使用梯度下降法求取最小值
# ### $2x^4-3x-20$

# %%
# 目標函數(損失函數)
f = lambda x: 2 * x ** 4 - 3 * x - 20 

# 目標函數的一階導數:dy/dx=2*x
df = lambda x: 8 * x ** 2 - 3

# 設定中文字型
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']  
# 矯正負號
plt.rcParams['axes.unicode_minus'] = False

color = 'r'    
t = np.arange(-6.0, 6.0, 0.01)
plt.plot(t, f(t), c='b');

# %%
# 超參數(Hyperparameters)
w_start = 5     # 起始權重 -5, -3
epochs = 1500     # 執行週期數 
lr = 0.01        # 學習率 0.01, 0.9

# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
w = GD(w_start, epochs, lr=lr) 
print('w的變化軌跡：', np.around(w, 8))

# 設定中文字型
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']  
# 矯正負號
plt.rcParams['axes.unicode_minus'] = False

color = 'r'    
t = np.arange(-6.0, 6.0, 0.01)
plt.plot(t, f(t), c='b')
plt.plot(w, f(w), c=color, label='lr={}'.format(lr))    
plt.scatter(w, f(w), c=color, ) 

plt.title('梯度下降法', fontsize=20)
plt.xlabel('W', fontsize=20)
plt.ylabel('損失函數', fontsize=20)
plt.show()
# Out:
# w的變化軌跡： [5.         3.03       2.325528   ... 0.61237244 0.61237244 0.61237244]

# %%
from sympy.calculus.util import minimum, maximum, Interval, stationary_points
from sympy import Symbol

x = Symbol('x')
f = 2 * x ** 4 - 3 * x - 20 
# ivl = Interval(0,1000)
# maximum(f, x, ivl), stationary_points(f, x, ivl)
minimum(f, x), stationary_points(f, x)
# Out:
# (-20 - 9*3**(1/3)/8, {3**(1/3)/2})

# %%
-20 - 9*3**(1/3)/8, 3**(1/3)/2
# Out:
# (-21.622530766595833, 0.7211247851537042)

# %% [markdown]
# ## 範例3. 複雜函數
# ### $sin(x) * e^(-0.1*(x-0.6)^2) $

# %%
from sympy import *
import math

x = Symbol('x')
y = sin(x)* E ** (-0.1*(x-0.6)**2)
print(y)
yprime = y.diff(x)

# 目標函數
def f(x_value): return math.sin(x_value) * math.e ** (-0.1*(x_value-0.6)**2)

# 目標函數一階導數:dy/dx
df = lambda x_value: yprime.subs(x, x_value).evalf()
# Out:
# exp(-0.1*(x - 0.6)**2)*sin(x)

# %%
# 超參數(Hyperparameters)
w_start = -3     # 起始權重
epochs = 1500  # 執行週期數 
lr = 0.01      # 學習率 

# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
w = GD(w_start, epochs, lr=lr) 
print('w的變化軌跡：', np.around(w, 2))

color = 'r'    
t = np.arange(-6.0, 6.0, 0.01)
plt.plot(t, [f(x) for x in t], c='b')
plt.plot(w, [f(x) for x in w], c=color, label='lr={}'.format(lr))    
plt.scatter(w, [f(x) for x in w], c=color, ) 

plt.title('梯度下降法', fontsize=20)
plt.xlabel('w', fontsize=20)
plt.ylabel('損失函數', fontsize=20)
plt.show()
# Out:
# w的變化軌跡： [-3.   -3.   -2.99 ... -1.22 -1.22 -1.22]

# %% [markdown]
# # 迴歸線求解
# ### https://ithelp.ithome.com.tw/articles/10211747
# ## y=wx+b，求解兩個變數w、b
# ### 範例：python 04_linear_regression_sgd.py
